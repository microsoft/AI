# %% [markdown]
# # Test our scripts locally

# %% [markdown]
# In this tutorial, we have a pretrained style transfer model that is used on a video to apply style transfer to each frame of the video.
#
# In this notebook, we test each of our python scripts locally to see that they perform as intended. We will test the following:
# - `scripts/preprocess_video.py` - which splits up the video into individually frames
# - `scripts/style_transfer.py` - which applies the style transfer algorithm to each image
# - `scripts/postprocess_video.py` - which stitches the style transfered images back together
#
# The final video will have style transfer applied to each frame.

# %% [markdown]
# ---

# %% [markdown]
# Import torch which is used to detect gpu availability

# %%
import torch

# %% [markdown]
# A create a directory to perform the local testing in.

# %%
# !mkdir local_test_orangutan

# %% [markdown]
# Download a video to test with.

# %%
# !wget https://happypathspublic.blob.core.windows.net/videos/orangutan.mp4
# Out:
# --2019-01-30 04:33:04--  https://happypathspublic.blob.core.windows.net/videos/orangutan.mp4
# Resolving happypathspublic.blob.core.windows.net (happypathspublic.blob.core.windows.net)... 52.239.214.164
# Connecting to happypathspublic.blob.core.windows.net (happypathspublic.blob.core.windows.net)|52.239.214.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7961293 (7.6M) [video/mp4]
# Saving to: ‘orangutan.mp4’
#
# orangutan.mp4       100%[===================>]   7.59M  --.-KB/s    in 0.04s
#
# 2019-01-30 04:33:04 (187 MB/s) - ‘orangutan.mp4’ saved [7961293/7961293]

# %% [markdown]
# Take a look at what the original video looks like:

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="orangutan.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="orangutan.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ### Testing the preprocessing script

# %%
# !python scripts/preprocess_video.py \
    --input-video orangutan.mp4 \
    --output-audio local_test_orangutan/audio.aac \
    --output-images local_test_orangutan/input_frames
# Out:
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 4.8.2 (GCC) 20140120 (Red Hat 4.8.2-15)
#   configuration: --prefix=/home/jiata/anaconda3/envs/batchscoringdl_aml --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'orangutan.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:27.48, start: 0.000000, bitrate: 2317 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 720x720, 2242 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, adts, to 'local_test_orangutan/audio.aac/audio.aac':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(eng): Audio: aac (LC), 48000 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.18.100 aac
# size=     242kB time=00:00:27.45 bitrate=  72.2kbits/s speed= 158x
# video:0kB audio:233kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.777506%
# [aac @ 0x17b5180] Qavg: 424.962
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'orangutan.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:27.48, start: 0.000000, bitrate: 2317 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 720x720, 2242 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x23c6740] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'local_test_orangutan/input_frames/%05d_video.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 720x720, q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.18.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  823 fps=293 q=24.8 Lsize=N/A time=00:00:27.43 bitrate=N/A speed=9.78x
# video:17559kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ### Testing the style transfer script

# %% [markdown]
# Create a directory for output frames - frames that have been processed by the style transfer script.

# %%
# !mkdir local_test_orangutan/output_frames

# %% [markdown]
# Apply style transfer

# %%
# !python scripts/style_transfer.py \
    --model-dir models \
    --cuda {1 if torch.cuda.is_available() else 0} \
    --content-dir local_test_orangutan/input_frames \
    --output-dir local_test_orangutan/output_frames
# Out:
# Processing 00013_video.jpg
# /home/jiata/anaconda3/envs/batchscoringdl_aml/lib/python3.6/site-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# Processing 00034_video.jpg
# Processing 00478_video.jpg
# Processing 00607_video.jpg
# Processing 00565_video.jpg
# Processing 00078_video.jpg
# Processing 00328_video.jpg
# Processing 00465_video.jpg
# Processing 00045_video.jpg
# Processing 00503_video.jpg
# Processing 00229_video.jpg
# Processing 00734_video.jpg
# Processing 00190_video.jpg
# Processing 00810_video.jpg
# Processing 00808_video.jpg
# Processing 00566_video.jpg
# Processing 00197_video.jpg
# Processing 00267_video.jpg
# Processing 00111_video.jpg
# Processing 00404_video.jpg
# Processing 00233_video.jpg
# Processing 00228_video.jpg
# Processing 00821_video.jpg
# Processing 00501_video.jpg
# Processing 00695_video.jpg
# Processing 00514_video.jpg
# Processing 00428_video.jpg
# Processing 00366_video.jpg
# Processing 00048_video.jpg
# Processing 00176_video.jpg
# Processing 00313_video.jpg
# Processing 00264_video.jpg
# Processing 00634_video.jpg
# Processing 00638_video.jpg
# Processing 00804_video.jpg
# Processing 00768_video.jpg
# Processing 00457_video.jpg
# Processing 00450_video.jpg
# Processing 00343_video.jpg
# Processing 00315_video.jpg
# Processing 00050_video.jpg
# Processing 00772_video.jpg
# Processing 00717_video.jpg
# Processing 00475_video.jpg
# Processing 00502_video.jpg
# Processing 00419_video.jpg
# Processing 00372_video.jpg
# Processing 00348_video.jpg
# Processing 00436_video.jpg
# Processing 00206_video.jpg
# Processing 00556_video.jpg
# Processing 00312_video.jpg
# Processing 00318_video.jpg
# Processing 00474_video.jpg
# Processing 00528_video.jpg
# Processing 00547_video.jpg
# Processing 00347_video.jpg
# Processing 00369_video.jpg
# Processing 00059_video.jpg
# Processing 00210_video.jpg
# Processing 00558_video.jpg
# Processing 00271_video.jpg
# Processing 00410_video.jpg
# Processing 00191_video.jpg
# Processing 00104_video.jpg
# Processing 00584_video.jpg
# Processing 00194_video.jpg
# Processing 00656_video.jpg
# Processing 00534_video.jpg
# Processing 00545_video.jpg
# Processing 00321_video.jpg
# Processing 00678_video.jpg
# Processing 00412_video.jpg
# Processing 00295_video.jpg
# Processing 00811_video.jpg
# Processing 00166_video.jpg
# Processing 00091_video.jpg
# Processing 00099_video.jpg
# Processing 00600_video.jpg
# Processing 00537_video.jpg
# Processing 00688_video.jpg
# Processing 00117_video.jpg
# Processing 00543_video.jpg
# Processing 00774_video.jpg
# Processing 00472_video.jpg
# Processing 00092_video.jpg
# Processing 00053_video.jpg
# Processing 00646_video.jpg
# Processing 00721_video.jpg
# Processing 00674_video.jpg
# Processing 00578_video.jpg
# Processing 00459_video.jpg
# Processing 00564_video.jpg
# Processing 00803_video.jpg
# Processing 00799_video.jpg
# Processing 00379_video.jpg
# Processing 00198_video.jpg
# Processing 00544_video.jpg
# Processing 00765_video.jpg
# Processing 00694_video.jpg
# Processing 00278_video.jpg
# Processing 00202_video.jpg
# Processing 00535_video.jpg
# Processing 00559_video.jpg
# Processing 00359_video.jpg
# Processing 00588_video.jpg
# Processing 00151_video.jpg
# Processing 00155_video.jpg
# Processing 00340_video.jpg
# Processing 00107_video.jpg
# Processing 00703_video.jpg
# Processing 00773_video.jpg
# Processing 00433_video.jpg
# Processing 00441_video.jpg
# Processing 00691_video.jpg
# Processing 00009_video.jpg
# Processing 00657_video.jpg
# Processing 00109_video.jpg
# Processing 00114_video.jpg
# Processing 00149_video.jpg
# Processing 00222_video.jpg
# Processing 00286_video.jpg
# Processing 00214_video.jpg
# Processing 00448_video.jpg
# Processing 00644_video.jpg
# Processing 00138_video.jpg
# Processing 00254_video.jpg
# Processing 00018_video.jpg
# Processing 00052_video.jpg
# Processing 00054_video.jpg
# Processing 00096_video.jpg
# Processing 00179_video.jpg
# Processing 00329_video.jpg
# Processing 00306_video.jpg
# Processing 00699_video.jpg
# Processing 00645_video.jpg
# Processing 00793_video.jpg
# Processing 00110_video.jpg
# Processing 00031_video.jpg
# Processing 00520_video.jpg
# Processing 00178_video.jpg
# Processing 00387_video.jpg
# Processing 00401_video.jpg
# Processing 00201_video.jpg
# Processing 00273_video.jpg
# Processing 00392_video.jpg
# Processing 00690_video.jpg
# Processing 00521_video.jpg
# Processing 00818_video.jpg
# Processing 00563_video.jpg
# Processing 00632_video.jpg
# Processing 00353_video.jpg
# Processing 00398_video.jpg
# Processing 00551_video.jpg
# Processing 00483_video.jpg
# Processing 00123_video.jpg
# Processing 00665_video.jpg
# Processing 00408_video.jpg
# Processing 00817_video.jpg
# Processing 00517_video.jpg
# Processing 00454_video.jpg
# Processing 00259_video.jpg
# Processing 00035_video.jpg
# Processing 00324_video.jpg
# Processing 00490_video.jpg
# Processing 00473_video.jpg
# Processing 00555_video.jpg
# Processing 00709_video.jpg
# Processing 00381_video.jpg
# Processing 00539_video.jpg
# Processing 00455_video.jpg
# Processing 00550_video.jpg
# Processing 00622_video.jpg
# Processing 00507_video.jpg
# Processing 00063_video.jpg
# Processing 00373_video.jpg
# Processing 00685_video.jpg
# Processing 00755_video.jpg
# Processing 00298_video.jpg
# Processing 00352_video.jpg
# Processing 00245_video.jpg
# Processing 00185_video.jpg
# Processing 00187_video.jpg
# Processing 00594_video.jpg
# Processing 00183_video.jpg
# Processing 00334_video.jpg
# Processing 00595_video.jpg
# Processing 00095_video.jpg
# Processing 00293_video.jpg
# Processing 00580_video.jpg
# Processing 00008_video.jpg
# Processing 00789_video.jpg
# Processing 00320_video.jpg
# Processing 00621_video.jpg
# Processing 00451_video.jpg
# Processing 00146_video.jpg
# Processing 00815_video.jpg
# Processing 00722_video.jpg
# Processing 00735_video.jpg
# Processing 00119_video.jpg
# Processing 00628_video.jpg
# Processing 00084_video.jpg
# Processing 00427_video.jpg
# Processing 00495_video.jpg
# Processing 00736_video.jpg
# Processing 00239_video.jpg
# Processing 00127_video.jpg
# Processing 00065_video.jpg
# Processing 00257_video.jpg
# Processing 00783_video.jpg
# Processing 00299_video.jpg
# Processing 00269_video.jpg
# Processing 00368_video.jpg
# Processing 00822_video.jpg
# Processing 00172_video.jpg
# Processing 00552_video.jpg
# Processing 00759_video.jpg
# Processing 00780_video.jpg
# Processing 00409_video.jpg
# Processing 00339_video.jpg
# Processing 00302_video.jpg
# Processing 00331_video.jpg
# Processing 00705_video.jpg
# Processing 00133_video.jpg
# Processing 00261_video.jpg
# Processing 00627_video.jpg
# Processing 00029_video.jpg
# Processing 00335_video.jpg
# Processing 00344_video.jpg
# Processing 00106_video.jpg
# Processing 00270_video.jpg
# Processing 00702_video.jpg
# Processing 00397_video.jpg
# Processing 00121_video.jpg
# Processing 00158_video.jpg
# Processing 00541_video.jpg
# Processing 00766_video.jpg
# Processing 00413_video.jpg
# Processing 00756_video.jpg
# Processing 00274_video.jpg
# Processing 00617_video.jpg
# Processing 00181_video.jpg
# Processing 00332_video.jpg
# Processing 00157_video.jpg
# Processing 00667_video.jpg
# Processing 00147_video.jpg
# Processing 00204_video.jpg
# Processing 00532_video.jpg
# Processing 00326_video.jpg
# Processing 00068_video.jpg
# Processing 00604_video.jpg
# Processing 00023_video.jpg
# Processing 00051_video.jpg
# Processing 00005_video.jpg
# Processing 00118_video.jpg
# Processing 00184_video.jpg
# Processing 00156_video.jpg
# Processing 00727_video.jpg
# Processing 00342_video.jpg
# Processing 00640_video.jpg
# Processing 00437_video.jpg
# Processing 00248_video.jpg
# Processing 00482_video.jpg
# Processing 00497_video.jpg
# Processing 00718_video.jpg
# Processing 00659_video.jpg
# Processing 00108_video.jpg
# Processing 00411_video.jpg
# Processing 00760_video.jpg
# Processing 00771_video.jpg
# Processing 00209_video.jpg
# Processing 00642_video.jpg
# Processing 00744_video.jpg
# Processing 00579_video.jpg
# Processing 00120_video.jpg
# Processing 00173_video.jpg
# Processing 00649_video.jpg
# Processing 00189_video.jpg
# Processing 00066_video.jpg
# Processing 00470_video.jpg
# Processing 00266_video.jpg
# Processing 00601_video.jpg
# Processing 00039_video.jpg
# Processing 00509_video.jpg
# Processing 00788_video.jpg
# Processing 00174_video.jpg
# Processing 00790_video.jpg
# Processing 00086_video.jpg
# Processing 00715_video.jpg
# Processing 00741_video.jpg
# Processing 00536_video.jpg
# Processing 00716_video.jpg
# Processing 00021_video.jpg
# Processing 00625_video.jpg
# Processing 00044_video.jpg
# Processing 00325_video.jpg
# Processing 00296_video.jpg
# Processing 00417_video.jpg
# Processing 00499_video.jpg
# Processing 00806_video.jpg
# Processing 00414_video.jpg
# Processing 00618_video.jpg
# Processing 00683_video.jpg
# Processing 00582_video.jpg
# Processing 00599_video.jpg
# Processing 00449_video.jpg
# Processing 00164_video.jpg
# Processing 00681_video.jpg
# Processing 00025_video.jpg
# Processing 00723_video.jpg
# Processing 00687_video.jpg
# Processing 00679_video.jpg
# Processing 00042_video.jpg
# Processing 00265_video.jpg
# Processing 00243_video.jpg
# Processing 00609_video.jpg
# Processing 00101_video.jpg
# Processing 00237_video.jpg
# Processing 00212_video.jpg
# Processing 00823_video.jpg
# Processing 00586_video.jpg
# Processing 00094_video.jpg
# Processing 00462_video.jpg
# Processing 00283_video.jpg
# Processing 00493_video.jpg
# Processing 00165_video.jpg
# Processing 00336_video.jpg
# Processing 00010_video.jpg
# Processing 00153_video.jpg
# Processing 00439_video.jpg
# Processing 00669_video.jpg
# Processing 00113_video.jpg
# Processing 00598_video.jpg
# Processing 00355_video.jpg
# Processing 00662_video.jpg
# Processing 00105_video.jpg
# Processing 00585_video.jpg
# Processing 00724_video.jpg
# Processing 00671_video.jpg
# Processing 00075_video.jpg
# Processing 00223_video.jpg
# Processing 00613_video.jpg
# Processing 00792_video.jpg
# Processing 00553_video.jpg
# Processing 00282_video.jpg
# Processing 00071_video.jpg
# Processing 00378_video.jpg
# Processing 00571_video.jpg
# Processing 00349_video.jpg
# Processing 00581_video.jpg
# Processing 00468_video.jpg
# Processing 00707_video.jpg
# Processing 00794_video.jpg
# Processing 00152_video.jpg
# Processing 00739_video.jpg
# Processing 00614_video.jpg
# Processing 00028_video.jpg
# Processing 00032_video.jpg
# Processing 00365_video.jpg
# Processing 00004_video.jpg
# Processing 00162_video.jpg
# Processing 00467_video.jpg
# Processing 00279_video.jpg
# Processing 00623_video.jpg
# Processing 00250_video.jpg
# Processing 00020_video.jpg
# Processing 00253_video.jpg
# Processing 00651_video.jpg
# Processing 00346_video.jpg
# Processing 00424_video.jpg
# Processing 00689_video.jpg
# Processing 00504_video.jpg
# Processing 00330_video.jpg
# Processing 00421_video.jpg
# Processing 00012_video.jpg
# Processing 00641_video.jpg
# Processing 00215_video.jpg
# Processing 00128_video.jpg
# Processing 00112_video.jpg
# Processing 00175_video.jpg
# Processing 00303_video.jpg
# Processing 00364_video.jpg
# Processing 00725_video.jpg
# Processing 00729_video.jpg
# Processing 00244_video.jpg
# Processing 00139_video.jpg
# Processing 00452_video.jpg
# Processing 00737_video.jpg
# Processing 00142_video.jpg
# Processing 00560_video.jpg
# Processing 00280_video.jpg
# Processing 00393_video.jpg
# Processing 00570_video.jpg
# Processing 00529_video.jpg
# Processing 00203_video.jpg
# Processing 00776_video.jpg
# Processing 00126_video.jpg
# Processing 00713_video.jpg
# Processing 00415_video.jpg
# Processing 00572_video.jpg
# Processing 00218_video.jpg
# Processing 00492_video.jpg
# Processing 00232_video.jpg
# Processing 00784_video.jpg
# Processing 00661_video.jpg
# Processing 00748_video.jpg
# Processing 00076_video.jpg
# Processing 00785_video.jpg
# Processing 00515_video.jpg
# Processing 00006_video.jpg
# Processing 00360_video.jpg
# Processing 00664_video.jpg
# Processing 00208_video.jpg
# Processing 00055_video.jpg
# Processing 00469_video.jpg
# Processing 00777_video.jpg
# Processing 00022_video.jpg
# Processing 00301_video.jpg
# Processing 00069_video.jpg
# Processing 00374_video.jpg
# Processing 00367_video.jpg
# Processing 00322_video.jpg
# Processing 00024_video.jpg
# Processing 00192_video.jpg
# Processing 00036_video.jpg
# Processing 00327_video.jpg
# Processing 00460_video.jpg
# Processing 00291_video.jpg
# Processing 00064_video.jpg
# Processing 00574_video.jpg
# Processing 00129_video.jpg
# Processing 00458_video.jpg
# Processing 00077_video.jpg
# Processing 00217_video.jpg
# Processing 00505_video.jpg
# Processing 00170_video.jpg
# Processing 00726_video.jpg
# Processing 00590_video.jpg
# Processing 00047_video.jpg
# Processing 00268_video.jpg
# Processing 00801_video.jpg
# Processing 00700_video.jpg
# Processing 00300_video.jpg
# Processing 00711_video.jpg
# Processing 00338_video.jpg
# Processing 00252_video.jpg
# Processing 00500_video.jpg
# Processing 00577_video.jpg
# Processing 00684_video.jpg
# Processing 00361_video.jpg
# Processing 00629_video.jpg
# Processing 00704_video.jpg
# Processing 00749_video.jpg
# Processing 00728_video.jpg
# Processing 00354_video.jpg
# Processing 00740_video.jpg
# Processing 00160_video.jpg
# Processing 00591_video.jpg
# Processing 00058_video.jpg
# Processing 00812_video.jpg
# Processing 00276_video.jpg
# Processing 00292_video.jpg
# Processing 00602_video.jpg
# Processing 00399_video.jpg
# Processing 00444_video.jpg
# Processing 00742_video.jpg
# Processing 00743_video.jpg
# Processing 00676_video.jpg
# Processing 00573_video.jpg
# Processing 00494_video.jpg
# Processing 00767_video.jpg
# Processing 00382_video.jpg
# Processing 00308_video.jpg
# Processing 00073_video.jpg
# Processing 00205_video.jpg
# Processing 00363_video.jpg
# Processing 00043_video.jpg
# Processing 00486_video.jpg
# Processing 00631_video.jpg
# Processing 00260_video.jpg
# Processing 00708_video.jpg
# Processing 00390_video.jpg
# Processing 00447_video.jpg
# Processing 00506_video.jpg
# Processing 00530_video.jpg
# Processing 00648_video.jpg
# Processing 00098_video.jpg
# Processing 00019_video.jpg
# Processing 00200_video.jpg
# Processing 00816_video.jpg
# Processing 00230_video.jpg
# Processing 00161_video.jpg
# Processing 00762_video.jpg
# Processing 00732_video.jpg
# Processing 00476_video.jpg
# Processing 00516_video.jpg
# Processing 00251_video.jpg
# Processing 00116_video.jpg
# Processing 00323_video.jpg
# Processing 00477_video.jpg
# Processing 00255_video.jpg
# Processing 00731_video.jpg
# Processing 00575_video.jpg
# Processing 00103_video.jpg
# Processing 00568_video.jpg
# Processing 00193_video.jpg
# Processing 00608_video.jpg
# Processing 00130_video.jpg
# Processing 00085_video.jpg
# Processing 00238_video.jpg
# Processing 00714_video.jpg
# Processing 00554_video.jpg
# Processing 00056_video.jpg
# Processing 00481_video.jpg
# Processing 00287_video.jpg
# Processing 00611_video.jpg
# Processing 00289_video.jpg
# Processing 00297_video.jpg
# Processing 00686_video.jpg
# Processing 00420_video.jpg
# Processing 00389_video.jpg
# Processing 00807_video.jpg
# Processing 00487_video.jpg
# Processing 00358_video.jpg
# Processing 00677_video.jpg
# Processing 00757_video.jpg
# Processing 00786_video.jpg
# Processing 00626_video.jpg
# Processing 00814_video.jpg
# Processing 00384_video.jpg
# Processing 00603_video.jpg
# Processing 00087_video.jpg
# Processing 00484_video.jpg
# Processing 00464_video.jpg
# Processing 00027_video.jpg
# Processing 00485_video.jpg
# Processing 00150_video.jpg
# Processing 00438_video.jpg
# Processing 00680_video.jpg
# Processing 00636_video.jpg
# Processing 00698_video.jpg
# Processing 00610_video.jpg
# Processing 00775_video.jpg
# Processing 00488_video.jpg
# Processing 00275_video.jpg
# Processing 00220_video.jpg
# Processing 00234_video.jpg
# Processing 00778_video.jpg
# Processing 00576_video.jpg
# Processing 00249_video.jpg
# Processing 00443_video.jpg
# Processing 00663_video.jpg
# Processing 00819_video.jpg
# Processing 00074_video.jpg
# Processing 00216_video.jpg
# Processing 00557_video.jpg
# Processing 00583_video.jpg
# Processing 00802_video.jpg
# Processing 00124_video.jpg
# Processing 00567_video.jpg
# Processing 00797_video.jpg
# Processing 00333_video.jpg
# Processing 00195_video.jpg
# Processing 00168_video.jpg
# Processing 00533_video.jpg
# Processing 00038_video.jpg
# Processing 00653_video.jpg
# Processing 00030_video.jpg
# Processing 00519_video.jpg
# Processing 00093_video.jpg
# Processing 00615_video.jpg
# Processing 00258_video.jpg
# Processing 00518_video.jpg
# Processing 00386_video.jpg
# Processing 00706_video.jpg
# Processing 00666_video.jpg
# Processing 00592_video.jpg
# Processing 00102_video.jpg
# Processing 00480_video.jpg
# Processing 00403_video.jpg
# Processing 00720_video.jpg
# Processing 00088_video.jpg
# Processing 00548_video.jpg
# Processing 00294_video.jpg
# Processing 00523_video.jpg
# Processing 00430_video.jpg
# Processing 00795_video.jpg
# Processing 00079_video.jpg
# Processing 00527_video.jpg
# Processing 00696_video.jpg
# Processing 00658_video.jpg
# Processing 00668_video.jpg
# Processing 00262_video.jpg
# Processing 00371_video.jpg
# Processing 00562_video.jpg
# Processing 00796_video.jpg
# Processing 00011_video.jpg
# Processing 00236_video.jpg
# Processing 00169_video.jpg
# Processing 00131_video.jpg
# Processing 00524_video.jpg
# Processing 00125_video.jpg
# Processing 00418_video.jpg
# Processing 00587_video.jpg
# Processing 00798_video.jpg
# Processing 00491_video.jpg
# Processing 00510_video.jpg
# Processing 00791_video.jpg
# Processing 00219_video.jpg
# Processing 00017_video.jpg
# Processing 00652_video.jpg
# Processing 00337_video.jpg
# Processing 00356_video.jpg
# Processing 00431_video.jpg
# Processing 00405_video.jpg
# Processing 00385_video.jpg
# Processing 00605_video.jpg
# Processing 00351_video.jpg
# Processing 00758_video.jpg
# Processing 00134_video.jpg
# Processing 00242_video.jpg
# Processing 00319_video.jpg
# Processing 00710_video.jpg
# Processing 00606_video.jpg
# Processing 00779_video.jpg
# Processing 00003_video.jpg
# Processing 00154_video.jpg
# Processing 00489_video.jpg
# Processing 00733_video.jpg
# Processing 00782_video.jpg
# Processing 00429_video.jpg
# Processing 00593_video.jpg
# Processing 00015_video.jpg
# Processing 00246_video.jpg
# Processing 00061_video.jpg
# Processing 00370_video.jpg
# Processing 00046_video.jpg
# Processing 00345_video.jpg
# Processing 00446_video.jpg
# Processing 00207_video.jpg
# Processing 00221_video.jpg
# Processing 00463_video.jpg
# Processing 00406_video.jpg
# Processing 00432_video.jpg
# Processing 00135_video.jpg
# Processing 00750_video.jpg
# Processing 00362_video.jpg
# Processing 00569_video.jpg
# Processing 00508_video.jpg
# Processing 00630_video.jpg
# Processing 00800_video.jpg
# Processing 00317_video.jpg
# Processing 00693_video.jpg
# Processing 00633_video.jpg
# Processing 00692_video.jpg
# Processing 00616_video.jpg
# Processing 00526_video.jpg
# Processing 00100_video.jpg
# Processing 00145_video.jpg
# Processing 00434_video.jpg
# Processing 00307_video.jpg
# Processing 00256_video.jpg
# Processing 00540_video.jpg
# Processing 00675_video.jpg
# Processing 00350_video.jpg
# Processing 00383_video.jpg
# Processing 00082_video.jpg
# Processing 00809_video.jpg
# Processing 00522_video.jpg
# Processing 00589_video.jpg
# Processing 00272_video.jpg
# Processing 00062_video.jpg
# Processing 00247_video.jpg
# Processing 00637_video.jpg
# Processing 00422_video.jpg
# Processing 00647_video.jpg
# Processing 00712_video.jpg
# Processing 00199_video.jpg
# Processing 00226_video.jpg
# Processing 00624_video.jpg
# Processing 00240_video.jpg
# Processing 00026_video.jpg
# Processing 00461_video.jpg
# Processing 00148_video.jpg
# Processing 00596_video.jpg
# Processing 00137_video.jpg
# Processing 00396_video.jpg
# Processing 00754_video.jpg
# Processing 00512_video.jpg
# Processing 00763_video.jpg
# Processing 00654_video.jpg
# Processing 00673_video.jpg
# Processing 00416_video.jpg
# Processing 00122_video.jpg
# Processing 00376_video.jpg
# Processing 00746_video.jpg
# Processing 00177_video.jpg
# Processing 00445_video.jpg
# Processing 00284_video.jpg
# Processing 00037_video.jpg
# Processing 00747_video.jpg
# Processing 00060_video.jpg
# Processing 00769_video.jpg
# Processing 00231_video.jpg
# Processing 00764_video.jpg
# Processing 00182_video.jpg
# Processing 00224_video.jpg
# Processing 00719_video.jpg
# Processing 00290_video.jpg
# Processing 00188_video.jpg
# Processing 00311_video.jpg
# Processing 00213_video.jpg
# Processing 00761_video.jpg
# Processing 00140_video.jpg
# Processing 00014_video.jpg
# Processing 00701_video.jpg
# Processing 00670_video.jpg
# Processing 00067_video.jpg
# Processing 00781_video.jpg
# Processing 00277_video.jpg
# Processing 00040_video.jpg
# Processing 00001_video.jpg
# Processing 00241_video.jpg
# Processing 00650_video.jpg
# Processing 00057_video.jpg
# Processing 00263_video.jpg
# Processing 00753_video.jpg
# Processing 00288_video.jpg
# Processing 00435_video.jpg
# Processing 00612_video.jpg
# Processing 00225_video.jpg
# Processing 00341_video.jpg
# Processing 00002_video.jpg
# Processing 00423_video.jpg
# Processing 00394_video.jpg
# Processing 00730_video.jpg
# Processing 00561_video.jpg
# Processing 00314_video.jpg
# Processing 00391_video.jpg
# Processing 00080_video.jpg
# Processing 00513_video.jpg
# Processing 00496_video.jpg
# Processing 00380_video.jpg
# Processing 00655_video.jpg
# Processing 00357_video.jpg
# Processing 00132_video.jpg
# Processing 00738_video.jpg
# Processing 00090_video.jpg
# Processing 00186_video.jpg
# Processing 00097_video.jpg
# Processing 00643_video.jpg
# Processing 00660_video.jpg
# Processing 00453_video.jpg
# Processing 00375_video.jpg
# Processing 00081_video.jpg
# Processing 00072_video.jpg
# Processing 00388_video.jpg
# Processing 00813_video.jpg
# Processing 00440_video.jpg
# Processing 00144_video.jpg
# Processing 00672_video.jpg
# Processing 00466_video.jpg
# Processing 00639_video.jpg
# Processing 00007_video.jpg
# Processing 00285_video.jpg
# Processing 00141_video.jpg
# Processing 00751_video.jpg
# Processing 00597_video.jpg
# Processing 00805_video.jpg
# Processing 00049_video.jpg
# Processing 00697_video.jpg
# Processing 00456_video.jpg
# Processing 00745_video.jpg
# Processing 00546_video.jpg
# Processing 00281_video.jpg
# Processing 00070_video.jpg
# Processing 00542_video.jpg
# Processing 00425_video.jpg
# Processing 00620_video.jpg
# Processing 00211_video.jpg
# Processing 00041_video.jpg
# Processing 00538_video.jpg
# Processing 00171_video.jpg
# Processing 00089_video.jpg
# Processing 00471_video.jpg
# Processing 00304_video.jpg
# Processing 00752_video.jpg
# Processing 00770_video.jpg
# Processing 00196_video.jpg
# Processing 00511_video.jpg
# Processing 00682_video.jpg
# Processing 00442_video.jpg
# Processing 00167_video.jpg
# Processing 00016_video.jpg
# Processing 00498_video.jpg
# Processing 00309_video.jpg
# Processing 00395_video.jpg
# Processing 00136_video.jpg
# Processing 00235_video.jpg
# Processing 00310_video.jpg
# Processing 00635_video.jpg
# Processing 00180_video.jpg
# Processing 00619_video.jpg
# Processing 00115_video.jpg
# Processing 00407_video.jpg
# Processing 00316_video.jpg
# Processing 00820_video.jpg
# Processing 00549_video.jpg
# Processing 00143_video.jpg
# Processing 00479_video.jpg
# Processing 00305_video.jpg
# Processing 00033_video.jpg
# Processing 00400_video.jpg
# Processing 00159_video.jpg
# Processing 00163_video.jpg
# Processing 00402_video.jpg
# Processing 00531_video.jpg
# Processing 00227_video.jpg
# Processing 00083_video.jpg
# Processing 00787_video.jpg
# Processing 00377_video.jpg
# Processing 00525_video.jpg
# Processing 00426_video.jpg

# %% [markdown]
# ### Testing the postprocessing script

# %% [markdown]
# The script will output a new video named `{video_name}_processed.mp4`.

# %%
# !python scripts/postprocess_video.py \
    --images-dir local_test_orangutan/output_frames \
    --input-audio local_test_orangutan/audio.aac \
    --video orangutan \
    --output-dir local_test_orangutan
# Out:
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 4.8.2 (GCC) 20140120 (Red Hat 4.8.2-15)
#   configuration: --prefix=/home/jiata/anaconda3/envs/batchscoringdl_aml --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, image2, from 'local_test_orangutan/output_frames/%05d_video.jpg':
#   Duration: 00:00:27.43, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 720x720 [SAR 1:1 DAR 1:1], 30 fps, 30 tbr, 30 tbn, 30 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x164a440] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x15c6d40] using SAR=1/1
# [libx264 @ 0x15c6d40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x15c6d40] profile High, level 3.1
# [libx264 @ 0x15c6d40] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=9 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=20.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'local_test_orangutan/video_without_audio.mp4':
#   Metadata:
#     encoder         : Lavf58.12.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 720x720 [SAR 1:1 DAR 1:1], q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc58.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  823 fps= 50 q=-1.0 Lsize=   81525kB time=00:00:27.33 bitrate=24433.6kbits/s speed=1.67x    8x
# video:81514kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013480%
# [libx264 @ 0x15c6d40] frame I:8     Avg QP:25.50  size:143834
# [libx264 @ 0x15c6d40] frame P:210   Avg QP:28.07  size:115876
# [libx264 @ 0x15c6d40] frame B:605   Avg QP:29.44  size: 95843
# [libx264 @ 0x15c6d40] consecutive B-frames:  1.6%  0.7%  1.5% 96.2%
# [libx264 @ 0x15c6d40] mb I  I16..4:  0.1% 94.5%  5.4%
# [libx264 @ 0x15c6d40] mb P  I16..4:  0.1% 52.5% 14.1%  P16..4:  4.5% 14.3% 14.5%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x15c6d40] mb B  I16..4:  0.2% 14.7% 17.8%  B16..8: 10.5% 29.5% 23.1%  direct: 3.8%  skip: 0.5%  L0:38.6% L1:27.1% BI:34.3%
# [libx264 @ 0x15c6d40] 8x8 transform intra:59.8% inter:75.0%
# [libx264 @ 0x15c6d40] coded y,uvDC,uvAC intra: 95.2% 99.2% 82.3% inter: 88.8% 92.2% 35.8%
# [libx264 @ 0x15c6d40] i16 v,h,dc,p: 28% 13%  7% 52%
# [libx264 @ 0x15c6d40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 10% 23%  9% 10% 11%  6%  9%  8%
# [libx264 @ 0x15c6d40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 10% 15% 10% 13% 11%  9% 11%  8%
# [libx264 @ 0x15c6d40] i8c dc,h,v,p: 43% 20% 24% 13%
# [libx264 @ 0x15c6d40] Weighted P-Frames: Y:3.3% UV:1.0%
# [libx264 @ 0x15c6d40] ref P L0: 28.4% 16.7% 30.9% 23.5%  0.6%
# [libx264 @ 0x15c6d40] ref B L0: 67.0% 24.7%  8.3%
# [libx264 @ 0x15c6d40] ref B L1: 84.5% 15.5%
# [libx264 @ 0x15c6d40] kb/s:24341.14
# ffmpeg version 4.0.2 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 4.8.2 (GCC) 20140120 (Red Hat 4.8.2-15)
#   configuration: --prefix=/home/jiata/anaconda3/envs/batchscoringdl_aml --disable-doc --disable-openssl --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-cxxflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-lpthread -lm -lz' --enable-zlib --enable-pic --enable-pthreads --enable-gpl --enable-version3 --enable-hardcoded-tables --enable-avresample --enable-libfreetype --enable-gnutls --enable-libx264 --enable-libopenh264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'local_test_orangutan/video_without_audio.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:27.43, start: 0.000000, bitrate: 24344 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 720x720 [SAR 1:1 DAR 1:1], 24341 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# [aac @ 0x1ca1380] Estimating duration from bitrate, this may be inaccurate
# Input #1, aac, from 'local_test_orangutan/audio.aac/audio.aac':
#   Duration: 00:00:27.96, bitrate: 70 kb/s
#     Stream #1:0: Audio: aac (LC), 48000 Hz, mono, fltp, 70 kb/s
# Output #0, mp4, to 'local_test_orangutan/orangutan_processed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 720x720 [SAR 1:1 DAR 1:1], q=2-31, 24341 kb/s, 30 fps, 30 tbr, 15360 tbn, 15360 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 70 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  823 fps=0.0 q=-1.0 Lsize=   81778kB time=00:00:27.45 bitrate=24400.0kbits/s speed= 345x
# video:81514kB audio:242kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.026915%

# %% [markdown]
# ### Check that the video output looks right

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="local_test_orangutan/orangutan_processed.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="local_test_orangutan/orangutan_processed.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ---

# %% [markdown]
# You are now ready to move on to the [next notebook](02_setup_aml.ipynb).
